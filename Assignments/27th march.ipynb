# %%
"""
Word Pairs with Explanation

1. Car – Automobile
Similarity Level: Very High 
Explanation:
Both words mean the same thing (a motor vehicle).
Automobile is just a more formal term for car.
These are synonyms

2. Teacher – Instructor
Similarity Level: High 
Explanation:
Both refer to a person who teaches.
Slight difference: Instructor is often used in professional or training contexts.
Meaning is very close with minor contextual variation

3. Dog – Animal
Similarity Level: Moderate 
Explanation:
A dog is a type of animal, but animal is a broader category.
This is a hierarchical relationship (hypernym)

4. Hot – Cold
Similarity Level: Low ❌ (Opposite meaning)
Explanation:
These words are opposites (antonyms).
They are related but represent completely different meanings.
Semantic relation exists, but similarity is low

5. Book – Library
Similarity Level: Moderate 
Explanation:
A library is a place where books are stored.
They are related but not similar in meaning.
This is an associative relationship

"""

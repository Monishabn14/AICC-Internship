# %%
"""
1. Resume Prompt

Weak Prompt: "Make a resume for me."
Strong Prompt: "Create a professional resume for a 3rd-year Computer Science engineering student skilled in Python, Machine Learning, and Web Development. Include sections: education, skills, projects, and achievements. Keep it one page and ATS-friendly."
Comparison:
Weak prompt → vague, incomplete
Strong prompt → clear, structured, targeted output

2. Business Idea Prompt

Weak Prompt:"Give me a business idea."
Strong Prompt: "Suggest a low-investment business idea for a college student in India, related to AI or technology. Include target audience, cost estimate, and potential profit."
Comparison:
Weak → generic ideas
Strong → practical, context-specific ideas

3. Study Plan Prompt

Weak Prompt:"Help me study."
Strong Prompt:"Create a 2-week study plan for learning Python basics for a beginner. Allocate daily 2 hours, include topics, practice tasks, and revision schedule."
Comparison:
Weak → unclear output
Strong → detailed and actionable plan

4. Coding Help Prompt

Weak Prompt:"Fix my code."
Strong Prompt:"Fix this Python code for calculating average marks. Explain the error and provide corrected code with comments."
Comparison:
Weak → lacks context
Strong → includes purpose + expectation

"""
